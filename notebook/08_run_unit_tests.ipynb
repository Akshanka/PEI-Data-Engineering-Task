# %% [markdown]
# # Unit Test Runner
#
# This notebook runs all unit tests in the `tests/` folder using pytest.
#
# **Instructions:**
# 1. Run Cell 2 to install dependencies (one-time setup)
# 2. Run Cell 3 to restart Python after installation
# 3. Run Cell 4 to execute all 32 unit tests
#
# **Current Test Coverage:**
# - ✅ **32 tests** covering all transformation functions
# - ✅ Refined layer transformations (data cleaning, type casting)
# - ✅ Enriched layer transformations (joins, aggregations)
# - ✅ Data quality utilities (DQX framework)
# - ✅ Common utility functions

# %%
# %pip install -r ../requirements.txt

# %%
dbutils.library.restartPython()

# %%
import sys
import os
import pytest

# Change to project root directory
project_root = "/Workspace/Users/akshaygalaxy23@gmail.com/PEI-Data-Engineering-Task"
os.chdir(project_root)

# Disable bytecode generation
sys.dont_write_bytecode = True

# Run pytest with verbose output
exit_code = pytest.main([
    "tests/",
    "-v",
    "--tb=short",
    "--color=yes"
])

print(f"\nTests completed with exit code: {exit_code}")
print("Exit codes: 0=all passed, 1=tests failed, 2=interrupted, 3=internal error, 4=usage error, 5=no tests collected")

# %% [markdown]
# ## Test Results
#
# After running the tests, check the output above for:
# - **PASSED** ✅ - Tests that executed successfully
# - **FAILED** ❌ - Tests with assertion failures
# - **ERROR** ⚠️ - Tests that couldn't run due to setup issues
#
# ### Test Suite Breakdown:
#
# | Test File | Tests | Purpose |
# |-----------|-------|----------|
# | `test_refined.py` | 5 | Data cleaning & type casting |
# | `test_enriched_orders.py` | 5 | Order enrichment with joins |
# | `test_enriched_dimensions.py` | 6 | Dimension table transformations |
# | `test_aggregations.py` | 6 | Profit aggregation & rounding |
# | `test_dqx_utils.py` | 6 | Data quality framework |
# | `test_common.py` | 4 | Utility functions |
# | **Total** | **32** | **Complete coverage** |
#
# ### Exit Codes:
# - `0` = All tests passed ✅
# - `1` = Some tests failed ❌
# - `2` = Interrupted
# - `3` = Internal error
# - `4` = Usage error
# - `5` = No tests collected
